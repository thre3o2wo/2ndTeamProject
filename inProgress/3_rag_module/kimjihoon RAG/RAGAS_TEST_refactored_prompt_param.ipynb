# %% [markdown]
# # RAGAS Evaluation Notebook (Clean)
#
# This notebook evaluates **baseline vs experiment** RAG pipelines using RAGAS and saves **summary/detail** outputs per run.

# %% [markdown]
# ## 🔧 수정 포인트(가장 자주 바꾸는 곳)
#
# 1) **SYSTEM_PROMPT_BASE / SYSTEM_PROMPT_EXP** (프롬프트 비교)
# 2) **base_cfg / exp_cfg** (파라미터 비교)
#
# 이 두 군데만 바꾸고 아래 실행 셀들을 돌리면, 같은 테스트셋으로 BASE vs EXP가 자동 비교됩니다.

# %%
# %pip install datasets

# %%
# %pip install ragas

# %%
# import sys, subprocess, textwrap

# def sh(cmd):
#     print(">", cmd)
#     r = subprocess.run(cmd, shell=True, capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# print("python:", sys.executable)
# print("version:", sys.version)

# # 현재 패키지 상태 확인
# sh("python -c \"import numpy; print('numpy', numpy.__version__)\"")
# sh("python -c \"import pyarrow; print('pyarrow', pyarrow.__version__)\"")
# sh("python -c \"import datasets; print('datasets', datasets.__version__)\"")

# %%
# import sys, subprocess

# def pip(cmd):
#     print(">", cmd)
#     r = subprocess.run([sys.executable, "-m", "pip"] + cmd.split(), capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# # 1) 제거
# pip("uninstall -y pyarrow datasets numpy")

# # 2) 재설치: numpy<2 + 최신 pyarrow + datasets(너가 쓰던 버전)
# pip("install numpy<2 pyarrow>=14 datasets==2.19.2")

# %%
# ---- RAGAS metrics: version-tolerant loader ----
def build_metrics():
    # A안: embeddings 의존 가능성이 큰 AnswerRelevancy는 빼고 "완주"부터
    # 1) 함수형 metric
    try:
        from ragas.metrics import context_precision, context_recall, faithfulness
        return [context_precision, context_recall, faithfulness]
    except Exception:
        pass

    # 2) 클래스형 metric
    try:
        from ragas.metrics import ContextPrecision, ContextRecall, Faithfulness
        return [ContextPrecision(), ContextRecall(), Faithfulness()]
    except Exception:
        pass

    # 3) fallback 탐색
    import ragas.metrics as m
    wanted = ["ContextPrecision", "ContextRecall", "Faithfulness"]
    found = []
    for name in wanted:
        if hasattr(m, name):
            found.append(getattr(m, name)())
    if found:
        return found

    raise ImportError(
        "RAGAS metrics import failed for A-plan (without AnswerRelevancy). "
        "Paste `pip show ragas` and `python -c \"import ragas; print(ragas.__version__)\"`."
    )

METRICS = build_metrics()
print("✅ METRICS:", [getattr(x, '__name__', x.__class__.__name__) for x in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness']

# %%
import ragas
print("ragas version:", getattr(ragas, "__version__", "unknown"))
# Out:
# ragas version: 0.3.2

# %%
from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy

METRICS = [context_precision, context_recall, faithfulness, answer_relevancy]
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']

# %% [markdown]
# ## 0) Environment & Paths

# %%
# ============================================================
# PATH CONFIG (only this cell is modified)
# ============================================================
import json
import pandas as pd
import sys, importlib
from pathlib import Path
from dotenv import load_dotenv

# ✅ 프로젝트 루트 (새 경로)
# PROJECT_ROOT = Path(r"C:\ai\source\chatbot_app")
PROJECT_ROOT = Path(r"C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app")

# ✅ 모듈 경로 (원래 쓰던 구조 그대로)
MODULE_DIR = PROJECT_ROOT / "modules"

# ✅ 환경변수
ENV_PATH = PROJECT_ROOT / ".env"

# ✅ 결과 저장 루트
RUNS_DIR = PROJECT_ROOT / "results" / "ragas_runs"

# ⭕️ 여기서 어떤 테스트셋 쓸지 네가 직접 선택
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_single.jsonl"
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_v1_from_docx.jsonl"
TESTSET_PATH = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"

# ------------------------------------------------------------
# setup
# ------------------------------------------------------------
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(MODULE_DIR))
importlib.invalidate_caches()

if ENV_PATH.exists():
    load_dotenv(ENV_PATH)

RUNS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("TESTSET_PATH:", TESTSET_PATH)
print("exists:", TESTSET_PATH.exists())
# Out:
# PROJECT_ROOT: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app
# TESTSET_PATH: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\ragas_testset_10_selected.jsonl
# exists: True

# %% [markdown]
# ## 1) Load testset (JSONL)

# %%
TESTSET_JSONL = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"  # change if needed
assert TESTSET_JSONL.exists(), f"❌ JSONL not found: {TESTSET_JSONL}"

rows = []
with open(TESTSET_JSONL, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        rows.append(json.loads(line))

print("✅ rows:", len(rows))
print("✅ keys example:", rows[0].keys())
pd.DataFrame(rows[:3])
# Out:
# ✅ rows: 10
# ✅ keys example: dict_keys(['question_id', 'question', 'ground_truth', 'contexts', 'meta'])
#   question_id                                           question  \
# 0        q010               조정에서 합의했는데 집주인이 안 지켜요. 이거 강제할 수 있나요?
# 1        q016  임대인이 보증금을 안 돌려줘서 제가 일부러 전입신고를 유지하고 있는데, 다른 집으로...
# 2        q002              계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요?
#
#                                         ground_truth  \
# 0  네, 강제할 수 있습니다.\n주택임대차보호법 제27조에 따르면,\n 제26조제4항 ...
# 1  다른 집으로 전입신고를 하면,\n 기존 주택에 대한 대항력을 상실하게 되어 임차인으...
# 2  아니요. 계약서에 1년이라고 적혀 있어도, 1년이 지나면 무조건 나가야 하는 것은 ...
#
#                                             contexts  \
# 0  [주택임대차보호법 제27조 제1항, 주택임대차보호법 시행령 제34조, 주택임대차보호...
# 1                                 [주택임대차보호법 제3조 제1항]
# 2                                 [주택임대차보호법 제4조 제1항]
#
#                                                 meta
# 0  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 1  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 2  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...

# %% [markdown]
# ## 2) Define baseline & experiment configs
#
# - Keep **base_cfg** stable.
# - Only put **changed knobs** in `exp_cfg = replace(base_cfg, ...)`.

# %%
from dataclasses import replace
from rag_module import RAGConfig

# =========================
# Base config (edit as needed)
# =========================
base_cfg = RAGConfig(
    # ---- LLM ----
    normalize_model="solar-pro2",
    generation_model="solar-pro2",
    temperature=0.1,
    normalize_temperature=0.0,

    # ---- Embedding ----
    embedding_backend="upstage",
    embedding_model="solar-embedding-1-large-passage",

    # ---- Dense Retrieval (A 담당: 고정) ----
    k_law=7,
    k_rule=7,
    k_case=3,
    search_multiplier=4,

    # ---- Hybrid Fusion ----
    hybrid_dense_weight=0.5,
    hybrid_sparse_weight=0.5,

    # ---- BM25 / Sparse ----
    enable_bm25=True,
    sparse_mode="auto",
    bm25_algorithm="okapi",
    bm25_k1=1.5,
    bm25_b=0.85,
    bm25_use_kiwi=True,

    # ---- BM25-title ----
    enable_bm25_title=True,
    bm25_title_field="title",
    hybrid_sparse_title_ratio=0.35,

    # ---- Rerank ----
    enable_rerank=True,
    rerank_model="rerank-multilingual-v3.0",
    rerank_threshold=0.22,
    rerank_max_documents=18,

    # ---- Output trimming ----
    bm25_max_doc_chars=3000,
    rerank_doc_max_chars=3000,

    # ---- Dedupe ----
    dedupe_key_fields=["chunk_id", "id"],
)


# =========================
# Experiment config (추천 안정판)
# =========================
exp_cfg = replace(
    base_cfg,
    # rerank: 과보수 방지 + 429 회피
    rerank_threshold=0.24,      # 0.26 → 0.24
    rerank_max_documents=10,    # 14 → 10 (Trial 안정)

    # 근거 문장 유지 (Faithfulness)
    bm25_max_doc_chars=2200,
    rerank_doc_max_chars=2200,
)
base_cfg, exp_cfg
# Out:
# (RAGConfig(normalize_model='solar-pro2', generation_model='solar-pro2', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=7, k_rule=7, k_case=3, search_multiplier=4, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.85, bm25_use_kiwi=True, bm25_max_doc_chars=3000, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.5, hybrid_sparse_weight=0.5, rrf_k=60, enable_rerank=True, rerank_threshold=0.22, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=18, rerank_doc_max_chars=3000, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=['chunk_id', 'id']),
#  RAGConfig(normalize_model='solar-pro2', generation_model='solar-pro2', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=7, k_rule=7, k_case=3, search_multiplier=4, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.85, bm25_use_kiwi=True, bm25_max_doc_chars=2200, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.5, hybrid_sparse_weight=0.5, rrf_k=60, enable_rerank=True, rerank_threshold=0.24, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=10, rerank_doc_max_chars=2200, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=['chunk_id', 'id']))

# %% [markdown]
# ## (추가) SYSTEM PROMPT 실험
#
# - 여기서 **프롬프트만** 바꿔도 BASE vs EXP 비교가 가능합니다.
# - 파이프라인이 `answer_with_trace(question, system_prompt=...)`를 지원하지 않더라도,
#   아래 `run_pipe_to_samples()`가 가능한 방식으로 우회해서 주입을 시도합니다.

# %%
# =========================
# SYSTEM PROMPT (BASE vs EXP)
# =========================
SYSTEM_PROMPT_BASE = """
당신은 대한민국 주택 임대차(전월세) 문제를 해결하는 법률정보 AI입니다.
아래 [참고 문서]를 참고하여, 사용자의 질문에 직접 답변하세요.

[최우선 규칙]
- 질문에 대한 결론을 가장 먼저 제시하세요.
- 질문과 직접 관련 없는 내용은 작성하지 마세요.
- 참고 문서에 없는 내용은 추론하거나 일반화하지 마세요.
- 판단이 어려운 경우, 근거 부족을 명확히 밝히세요.

[답변 형식 — 반드시 따르세요]
1. 결론  
   - 질문에 대해 가능한지 / 불가능한지 / 해야 하는지를
     단정적인 문장으로 먼저 제시하세요.

2. 이유  
   - 위 결론이 나오는 이유를
     참고 문서의 내용에 근거하여 설명하세요.
   - 문서의 취지·내용과 직접 연결되도록 작성하세요.

3. 한계 명시  
   - 참고 문서만으로 판단이 완전히 확정되지 않는 경우,
     그 한계를 한 문장으로만 밝히세요.
""".strip()


# ✅ EXP 프롬프트 (AnswerRelevancy 강화 + Faithfulness 안전장치 반영)
SYSTEM_PROMPT_EXP = """
당신은 대한민국 주택 임대차(전월세) 문제를 해결하는 법률정보 AI입니다.
아래 [참고 문서]를 참고하여, 사용자의 질문에 직접 답변하세요.

[최우선 규칙]
- 질문에 대한 결론을 가장 먼저 제시하세요.
- 질문에 없는 쟁점(일반론/배경설명/제도 소개)은 작성하지 마세요.
- 참고 문서에 없는 내용은 추론하거나 일반화하지 마세요.
- 판단이 어려운 경우, 근거 부족을 명확히 밝히세요.

[질문-정합(AnswerRelevancy) 강화 규칙]
- 답변은 반드시 사용자의 질문에 정면으로 대응해야 합니다.
- 결론 문장에는 질문의 핵심 대상(예: 계약, 보증금, 해지, 갱신 등)을
  최소 1회 이상 포함하세요.
- 질문 형식에 맞춰 결론 문장을 작성하되,
  참고 문서에 근거가 있는 경우에만 구조화하세요.
  - “가능한가?” → “가능합니다 / 불가능합니다”
  - “해야 하나?” → “해야 합니다 / 하지 않아도 됩니다”
  - “어떻게 하나?” → 참고 문서에 제시된 절차가 있는 경우에만,
                    문서에 나온 순서대로 작성하세요.
- 질문 요지를 벗어나는 부가 설명을 금지합니다.
- (내부 점검) 작성 전, ‘이 답변이 질문에 직접 답하고 있는가?’를 1회 확인하세요.

[답변 형식 — 반드시 따르세요]
1. 결론  
   - 질문에 대해 가능한지 / 불가능한지 / 해야 하는지를
     단정적인 문장으로 먼저 제시하세요.

2. 이유  
   - 위 결론이 나오는 이유를
     참고 문서에 명시된 핵심 근거 문장을 중심으로
     1~2문장으로 간결하게 설명하세요.
   - 문서의 취지·내용과 직접 연결되도록 작성하세요.

3. 한계 명시  
   - 참고 문서만으로 판단이 완전히 확정되지 않는 경우,
     그 한계를 한 문장으로만 밝히세요.
""".strip()

print("BASE prompt chars:", len(SYSTEM_PROMPT_BASE))
print("EXP  prompt chars:", len(SYSTEM_PROMPT_EXP))
# Out:
# BASE prompt chars: 454
# EXP  prompt chars: 899

# %% [markdown]
# ## 3) Build pipelines

# %%
# ============================================================
# ✅ Upstage (solar-pro2) generation 안정화: OpenAI-compatible env bridge
# - rag_module 내부가 OpenAI/LangChain(OpenAI-compatible) 클라이언트를 쓰는 경우를 대비
# - solar-pro2는 OpenAI 모델이 아니므로 base_url/api_key가 Upstage로 향해야 합니다.
# ============================================================

import os

# Required
if not os.environ.get("UPSTAGE_API_KEY"):
    raise RuntimeError("UPSTAGE_API_KEY가 없습니다. Upstage SOLAR Pro2 호출을 위해 환경변수를 설정하세요.")

def _ensure_upstage_solar_base_url(url: str) -> str:
    """Upstage OpenAI-compatible base_url을 /v1/solar로 강제합니다.
    - 흔한 실수: https://api.upstage.ai/v1  (solar prefix 없음) → /v1/chat/completions 로 나가서 401/invalid_key 발생
    """
    if not url:
        return "https://api.upstage.ai/v1/solar"
    u = url.rstrip("/")
    # 이미 solar면 그대로
    if u.endswith("/v1/solar") or "/v1/solar" in u:
        return u
    # v1까지만 있으면 solar를 붙임
    if u.endswith("/v1"):
        return u + "/solar"
    # 혹시 /solar만 있는 경우(v1 빠짐)는 그대로 두되, 추천은 v1/solar
    if u.endswith("/solar"):
        return u
    # 그 외는 안전하게 그대로 (사용자가 커스텀 프록시 쓰는 경우)
    return u

# Optional: if user didn't set it, default to Upstage SOLAR OpenAI-compatible endpoint
os.environ["UPSTAGE_BASE_URL"] = _ensure_upstage_solar_base_url(
    os.environ.get("UPSTAGE_BASE_URL", "https://api.upstage.ai/v1/solar")
)

# Bridge for libraries that look for OPENAI_* env vars (OpenAI-compatible)
# - IMPORTANT: OPENAI_BASE_URL도 반드시 /v1/solar로 맞춰야 generation이 정상 동작합니다.
os.environ["OPENAI_API_KEY"] = os.environ["UPSTAGE_API_KEY"]
os.environ["OPENAI_BASE_URL"] = os.environ["UPSTAGE_BASE_URL"]

print("✅ UPSTAGE_BASE_URL =", os.environ["UPSTAGE_BASE_URL"])
print("✅ OPENAI_BASE_URL  =", os.environ["OPENAI_BASE_URL"])
print("✅ OPENAI_API_KEY set:", bool(os.environ.get("OPENAI_API_KEY")))
# Out:
# ✅ UPSTAGE_BASE_URL = https://api.upstage.ai/v1/solar
# ✅ OPENAI_BASE_URL  = https://api.upstage.ai/v1/solar
# ✅ OPENAI_API_KEY set: True

# %%
from rag_module import create_pipeline

base_pipe = create_pipeline(config=base_cfg)
exp_pipe  = create_pipeline(config=exp_cfg)

print("✅ pipelines ready")
# Out:
# 2026-02-08 15:49:35,280 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-08 15:49:35,314 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-08 15:49:35,896 - rag_module - INFO - ✅ Kiwi 토크나이저 사용 (BM25)
# 2026-02-08 15:49:38,620 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-08 15:49:38,631 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-08 15:49:39,225 - rag_module - INFO - ✅ Kiwi 토크나이저 사용 (BM25)
# ✅ pipelines ready

# %% [markdown]
# ## 4) (Optional) Quick trace sanity check

# %%
# If your rag_module exposes a trace / debug method, call it here.
# Otherwise you can skip this cell.

# Example (adjust to your actual API):
# ans, trace = base_pipe.answer_with_trace("테스트 질문 ...")
# display(trace)

print("ℹ️ Skip or customize depending on your pipeline API.")
# Out:
# ℹ️ Skip or customize depending on your pipeline API.

# %% [markdown]
# ## 5) Build RAGAS samples from your pipeline outputs
#
# This converts each testset row into the RAGAS format:
# - `question`
# - `answer`
# - `contexts` (list[str])
# - `ground_truth`

# %%
def _to_text(c):
    """Return plain text for a context item (Document/dict/str)."""
    if c is None:
        return ""
    # LangChain Document
    if hasattr(c, "page_content"):
        return (c.page_content or "").strip()
    # dict-like
    if isinstance(c, dict):
        return (c.get("page_content") or c.get("text") or c.get("content") or "").strip()
    # already string
    return str(c).strip()

def shrink_contexts(ctxs, max_chars=2400, max_contexts=30):
    out = []
    for c in (ctxs or []):
        s = _to_text(c)
        if not s:
            continue
        out.append(s[:max_chars])
        if len(out) >= max_contexts:
            break
    return out

def row_get_ground_truth(r: dict):
    return r.get("ground_truth") or r.get("reference") or r.get("gt") or r.get("answer")

def _is_generation_error(ans: str) -> bool:
    s = (ans or "").strip()
    if not s:
        return True
    # 파이프에서 흔히 쓰는 에러 문구 패턴들
    keywords = [
        "오류가 발생", "에러가 발생", "답변 생성 중 오류", "generation error",
        "internal server error", "rate limit", "invalid api key", "unauthorized"
    ]
    return any(k.lower() in s.lower() for k in keywords)

def run_pipe_to_samples(pipe, rows, system_prompt=None, max_chars=2400, max_contexts=30, limit=None, fail_fast=True):
    """
    - fail_fast=True: 답변 생성/컨텍스트 수집이 실패하면 즉시 예외를 발생시켜
      '빈 결과/NaN'을 만들지 않게 합니다(추천).
    """
    samples = []
    n = len(rows) if limit is None else min(limit, len(rows))

    for i in range(n):
        r = rows[i]
        q = r.get("question") or r.get("query")
        if not q:
            continue

        # ✅ 파이프 호출 + 프롬프트 주입(가능한 방식으로 시도)
        try:
            if system_prompt:
                try:
                    out = pipe.answer_with_trace(q, system_prompt=system_prompt)
                except TypeError:
                    # 파이프라인이 system_prompt 인자를 받지 않는 경우: 속성/세터로 우회 시도
                    if hasattr(pipe, "set_system_prompt") and callable(getattr(pipe, "set_system_prompt")):
                        pipe.set_system_prompt(system_prompt)
                    elif hasattr(pipe, "system_prompt"):
                        try:
                            setattr(pipe, "system_prompt", system_prompt)
                        except Exception:
                            pass
                    elif hasattr(pipe, "prompt"):
                        try:
                            setattr(pipe, "prompt", system_prompt)
                        except Exception:
                            pass
                    out = pipe.answer_with_trace(q)
            else:
                out = pipe.answer_with_trace(q)
        except Exception as e:
            if fail_fast:
                raise RuntimeError(f"[PIPE CALL FAILED] i={i} q={q[:80]!r} err={type(e).__name__}: {e}") from e
            else:
                out = {"answer": "", "contexts": [], "trace": {"error": str(e), "type": type(e).__name__}}

        # out이 dict일 수도 있고, (answer, ctxs, trace) 튜플일 수도 있어서 안전 처리
        ans, ctxs, trace = "", [], None

        if isinstance(out, dict):
            ans = out.get("answer") or out.get("result") or out.get("output") or out.get("text") or ""
            ctxs = out.get("contexts") or out.get("context") or out.get("docs") or []
            trace = out.get("trace") or out.get("debug") or out.get("meta")
        elif isinstance(out, tuple):
            # 흔한 패턴들 대응
            if len(out) == 3:
                ans, ctxs, trace = out
            elif len(out) == 2:
                ans, ctxs = out
            elif len(out) == 1:
                ans = out[0]
        else:
            ans = str(out)

        ctxs_shrunk = shrink_contexts(ctxs, max_chars=max_chars, max_contexts=max_contexts)

        # ✅ "조용한 실패"를 막기 위한 검증
        if fail_fast:
            if _is_generation_error(ans):
                raise RuntimeError(
                    f"[GENERATION FAILED] i={i} q={q[:80]!r} ans={ans[:120]!r} "
                    f"(solar-pro2 호출/키/엔드포인트를 확인하세요)"
                )
            if not ctxs_shrunk:
                # 컨텍스트가 비면 Faithfulness/Precision/Recall이 무의미해짐
                raise RuntimeError(
                    f"[EMPTY CONTEXTS] i={i} q={q[:80]!r} (retrieval 결과가 비었습니다. 파이프 trace를 확인하세요)"
                )

        samples.append({
            "question": q,
            "answer": ans or "",
            "contexts": ctxs_shrunk,
            "ground_truth": row_get_ground_truth(r) or "",
            "_trace": trace,  # ✅ trace도 같이 보관(원하면 저장 가능)
        })

    return samples

# ✅ 스모크 테스트: 1문제만 먼저 (생성/컨텍스트가 정상인지 확인 후 전체 실행)
SMOKE_N = 1
_smoke_base = run_pipe_to_samples(base_pipe, rows, system_prompt=SYSTEM_PROMPT_BASE, limit=SMOKE_N, fail_fast=True)
_smoke_exp  = run_pipe_to_samples(exp_pipe,  rows, system_prompt=SYSTEM_PROMPT_EXP,  limit=SMOKE_N, fail_fast=True)
print("✅ SMOKE OK:", len(_smoke_base), len(_smoke_exp))

# ✅ 본 실행
BASE_SAMPLES = run_pipe_to_samples(base_pipe, rows, system_prompt=SYSTEM_PROMPT_BASE, limit=None, fail_fast=True)
EXP_SAMPLES  = run_pipe_to_samples(exp_pipe,  rows, system_prompt=SYSTEM_PROMPT_EXP,  limit=None, fail_fast=True)

print("✅ BASE_SAMPLES:", len(BASE_SAMPLES))
print("✅ EXP_SAMPLES :", len(EXP_SAMPLES))

pd.DataFrame([{k: v for k, v in BASE_SAMPLES[0].items() if k != "_trace"}])
# Out:
# 2026-02-08 15:49:42,586 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:49:42,596 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.
# 2026-02-08 15:49:42,597 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.'
# 2026-02-08 15:49:43,143 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:49:45,632 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:49:47,969 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:49:53,556 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:49:53,578 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:49:53,583 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:49:55,904 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:49:57,179 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:49:57,182 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 "집주인"만 명시되어 있어 "임대인"으로 단일 변환 적용하였습니다. "조정"은 사전 미등재로 유지하였습니다.
# 2026-02-08 15:49:57,182 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 "집주인"만 명시되어 있어 "임대인"으로 단일 변환 적용하였습니다. "조정"은 사전 미등재로 유지하였습니다.'
# 2026-02-08 15:49:57,824 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:00,541 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:02,981 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:08,609 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:08,613 - rag_module - INFO - 📌 Rerank selected=10 (threshold=0.24)
# 2026-02-08 15:50:08,614 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:11,193 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# ✅ SMOKE OK: 1 1
# 2026-02-08 15:50:12,144 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:12,146 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 "집주인"만 명시되어 있어 "조정"은 변환하지 않았습니다. 사용자 질문 의도 유지를 위해 "조정"은 원문을 유지하였습니다.
# 2026-02-08 15:50:12,147 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 "집주인"만 명시되어 있어 "조정"은 변환하지 않았습니다. 사용자 질문 의도 유지를 위해 "조정"은 원문을 유지하였습니다.'
# 2026-02-08 15:50:12,634 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:13,313 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:14,012 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:16,013 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:16,016 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:50:16,017 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:18,361 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:19,084 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:19,086 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?
# 2026-02-08 15:50:19,087 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?'
# 2026-02-08 15:50:19,547 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:20,210 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:21,346 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:23,296 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:23,299 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:50:23,301 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:25,531 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:27,507 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:27,509 - rag_module - INFO - 🔄 표준화된 질문: 계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요? → 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요?
#
# 변경된 질문:
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서)에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도(퇴거)를 해야 하나요?)
#
# ※ [수행 지침 2]에 따라 변경 전 단어 뒤에 괄호 처리했으나, 원문의 '나가야'는 '주택의인도'로 대체된 점을 추가로 명시했습니다. 다만 최종 출력 시 중복된 괄호 표현은 생략하고, 아래처럼 간결하게 제시합니다.
#
# **최종 출력:**
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서), 퇴거(주택의인도))
#
# ※ 단, [수행 지침 3]에 따라 추가 설명 없이 최종 텍스트만 출력합니다.
#
# **최종 답변:**
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서), 퇴거(주택의인도))
# 2026-02-08 15:50:27,510 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요? → 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요?
#
# 변경된 질문:
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서)에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도(퇴거)를 해야 하나요?)
#
# ※ [수행 지침 2]에 따라 변경 전 단어 뒤에 괄호 처리했으나, 원문의 '나가야'는 '주택의인도'로 대체된 점을 추가로 명시했습니다. 다만 최종 출력 시 중복된 괄호 표현은 생략하고, 아래처럼 간결하게 제시합니다.
#
# **최종 출력:**
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서), 퇴거(주택의인도))
#
# ※ 단, [수행 지침 3]에 따라 추가 설명 없이 최종 텍스트만 출력합니다.
#
# **최종 답변:**
# 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요? (계약서(임대차계약증서), 퇴거(주택의인도))'
# 2026-02-08 15:50:28,184 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:29,255 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:30,467 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:32,572 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:32,575 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:50:32,576 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:34,846 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:35,570 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:35,572 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?
# 2026-02-08 15:50:35,573 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?'
# 2026-02-08 15:50:36,021 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:36,955 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:37,813 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:39,401 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:39,404 - rag_module - INFO - 📌 Rerank selected=5 (threshold=0.22)
# 2026-02-08 15:50:39,405 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:41,180 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:41,623 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:41,625 - rag_module - INFO - 🔄 표준화된 질문: 경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?
# 2026-02-08 15:50:41,625 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?'
# 2026-02-08 15:50:42,184 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:43,084 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:43,752 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:45,626 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:45,629 - rag_module - INFO - 📌 Rerank selected=7 (threshold=0.22)
# 2026-02-08 15:50:45,630 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:48,210 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:48,859 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:48,861 - rag_module - INFO - 🔄 표준화된 질문: 계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?
# 2026-02-08 15:50:48,862 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?'
# 2026-02-08 15:50:49,323 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:50,483 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:51,153 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:53,028 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:50:53,034 - rag_module - INFO - 📌 Rerank selected=5 (threshold=0.22)
# 2026-02-08 15:50:53,035 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:50:55,278 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:56,138 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:50:56,140 - rag_module - INFO - 🔄 표준화된 질문: 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?
#
# ※ 참고: '이사'의 경우 문맥상 '주택의인도'로 변환되었으나, 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다. (예: "이사 가려면" → "임차주택을 명도하려면")
# 2026-02-08 15:50:56,141 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?
#
# ※ 참고: '이사'의 경우 문맥상 '주택의인도'로 변환되었으나, 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다. (예: "이사 가려면" → "임차주택을 명도하려면")'
# 2026-02-08 15:50:56,749 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:57,777 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:50:58,676 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:00,386 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:00,389 - rag_module - INFO - 📌 Rerank selected=1 (threshold=0.22)
# 2026-02-08 15:51:00,390 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:02,929 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:08,362 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:08,365 - rag_module - INFO - 🔄 표준화된 질문: 신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요? (집주인: 임대인, 건물주: 임대인, 주인집: 임대인, 임대업자: 임대인, 새주인: 임대인, 세입자: 임차인, 월세입자: 임차인, 세들어사는사람: 임차인, 임차자: 임차인, 입주자: 임차인, 부동산: 공인중개사, 중개인: 공인중개사, 중개소: 공인중개사, 빌라: 임차주택, 아파트: 임차주택, 오피스텔: 임차주택, 우리집: 임차주택, 거주지: 임차주택, 계약서: 임대차계약증서, 집문서: 임대차계약증서, 종이: 임대차계약증서, 보증금: 임대차보증금, 전세금: 임대차보증금, 보증보험: 보증금반환보증, 돈못받음: 보증금미반환, 안돌려줌: 보증금미반환, 못돌려받음: 보증금미반환, 월세: 차임, 관리비: 관리비, 연체: 차임연체, 밀림: 차임연체, 복비: 중개보수, 수수료: 중개보수, 중개비: 중개보수, 월세올리기: 차임증액, 인상: 증액, 더달라고함: 증액, 월세깎기: 차임감액, 할인: 감액, 내리기: 감액, 돈먼저받기: 우선변제권, 순위: 우선변제권, 안전장치: 대항력, 돌려받기: 보증금반환, 재계약: 계약갱신, 연장: 계약갱신, 갱신: 계약갱신, 갱신청구: 계약갱신요구권, 2년더: 계약갱신요구권, 2플러스2: 계약갱신요구권, 자동연장: 묵시적갱신, 묵시: 묵시적갱신, 연락없음: 묵시적갱신, 이사: 주택의인도, 짐빼기: 주택의인도, 퇴거: 주택의인도, 방빼: 계약해지, 중도해지: 계약해지, 주소옮기기: 주민등록, 전입신고: 주민등록, 주소지이전: 주민등록, 집주인바뀜: 임대인지위승계, 주인바뀜: 임대인지위승계, 매매: 임대인지위승계, 나가라고함: 계약갱신거절, 쫓겨남: 명도, 비워달라: 명도, 집고치기: 수선의무, 수리: 수선의무, 고쳐줘: 수선의무, 안고쳐줌: 수선의무위반, 곰팡이: 하자, 물샘: 누수, 보일러고장: 하자, 파손: 훼손, 깨끗이치우기: 원상회복의무, 원래대로해놓기: 원상회복, 청소비: 원상회복비용, 청소: 원상회복, 층간소음: 공동생활평온, 옆집소음: 방음, 개키우기: 반려동물특약, 담배: 흡연금지특약, 확정일자: 확정일자, 전입: 주민등록, 대항력: 대항력, 우선변제: 우선변제권, 최우선: 최우선변제권, 경매: 경매절차, 공매: 공매절차, 등기: 등기부등본, 등본: 등기부등본, 근저당: 근저당권, 가압류: 가압류, 가처분: 가처분, 깡통전세: 전세피해, 사기: 전세사기, 경매넘어감: 권리리스크, 내용증명: 내용증명, 소송: 소송, 민사: 민사소송, 조정위: 주택임대차분쟁조정위원회, 소송말고: 분쟁조정, 법원가기싫음: 분쟁조정, 집주인사망: 임차권승계, 자식상속: 임차권승계, 특약: 특약사항, 불공정: 강행규정위반, 독소조항: 불리한약정, 효력있나: 무효여부)
#
# ※ 참고: 사용자 질문의 "신축 빌라"는 용어 사전에 명시된 "빌라: 임차주택" 매핑에 따라 "신축 임차주택"으로 변환되었으며, "전세가"는 "임대차보증금"으로, "전세 계약"은 "임대차보증금 계약"으로 각각 변환되었습니다. "빌라" 외 다른 단어는 용어 사전에 없는 일반명사이므로 변환하지 않았습니다.
# 2026-02-08 15:51:08,366 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요? (집주인: 임대인, 건물주: 임대인, 주인집: 임대인, 임대업자: 임대인, 새주인: 임대인, 세입자: 임차인, 월세입자: 임차인, 세들어사는사람: 임차인, 임차자: 임차인, 입주자: 임차인, 부동산: 공인중개사, 중개인: 공인중개사, 중개소: 공인중개사, 빌라: 임차주택, 아파트: 임차주택, 오피스텔: 임차주택, 우리집: 임차주택, 거주지: 임차주택, 계약서: 임대차계약증서, 집문서: 임대차계약증서, 종이: 임대차계약증서, 보증금: 임대차보증금, 전세금: 임대차보증금, 보증보험: 보증금반환보증, 돈못받음: 보증금미반환, 안돌려줌: 보증금미반환, 못돌려받음: 보증금미반환, 월세: 차임, 관리비: 관리비, 연체: 차임연체, 밀림: 차임연체, 복비: 중개보수, 수수료: 중개보수, 중개비: 중개보수, 월세올리기: 차임증액, 인상: 증액, 더달라고함: 증액, 월세깎기: 차임감액, 할인: 감액, 내리기: 감액, 돈먼저받기: 우선변제권, 순위: 우선변제권, 안전장치: 대항력, 돌려받기: 보증금반환, 재계약: 계약갱신, 연장: 계약갱신, 갱신: 계약갱신, 갱신청구: 계약갱신요구권, 2년더: 계약갱신요구권, 2플러스2: 계약갱신요구권, 자동연장: 묵시적갱신, 묵시: 묵시적갱신, 연락없음: 묵시적갱신, 이사: 주택의인도, 짐빼기: 주택의인도, 퇴거: 주택의인도, 방빼: 계약해지, 중도해지: 계약해지, 주소옮기기: 주민등록, 전입신고: 주민등록, 주소지이전: 주민등록, 집주인바뀜: 임대인지위승계, 주인바뀜: 임대인지위승계, 매매: 임대인지위승계, 나가라고함: 계약갱신거절, 쫓겨남: 명도, 비워달라: 명도, 집고치기: 수선의무, 수리: 수선의무, 고쳐줘: 수선의무, 안고쳐줌: 수선의무위반, 곰팡이: 하자, 물샘: 누수, 보일러고장: 하자, 파손: 훼손, 깨끗이치우기: 원상회복의무, 원래대로해놓기: 원상회복, 청소비: 원상회복비용, 청소: 원상회복, 층간소음: 공동생활평온, 옆집소음: 방음, 개키우기: 반려동물특약, 담배: 흡연금지특약, 확정일자: 확정일자, 전입: 주민등록, 대항력: 대항력, 우선변제: 우선변제권, 최우선: 최우선변제권, 경매: 경매절차, 공매: 공매절차, 등기: 등기부등본, 등본: 등기부등본, 근저당: 근저당권, 가압류: 가압류, 가처분: 가처분, 깡통전세: 전세피해, 사기: 전세사기, 경매넘어감: 권리리스크, 내용증명: 내용증명, 소송: 소송, 민사: 민사소송, 조정위: 주택임대차분쟁조정위원회, 소송말고: 분쟁조정, 법원가기싫음: 분쟁조정, 집주인사망: 임차권승계, 자식상속: 임차권승계, 특약: 특약사항, 불공정: 강행규정위반, 독소조항: 불리한약정, 효력있나: 무효여부)
#
# ※ 참고: 사용자 질문의 "신축 빌라"는 용어 사전에 명시된 "빌라: 임차주택" 매핑에 따라 "신축 임차주택"으로 변환되었으며, "전세가"는 "임대차보증금"으로, "전세 계약"은 "임대차보증금 계약"으로 각각 변환되었습니다. "빌라" 외 다른 단어는 용어 사전에 없는 일반명사이므로 변환하지 않았습니다.'
# 2026-02-08 15:51:09,169 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:10,176 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:11,220 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:13,785 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:13,788 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:51:13,788 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:16,766 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:17,212 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:17,214 - rag_module - INFO - 🔄 표준화된 질문: 주민등록·확정일자(확정일자) 했는데, 확정일자부(확정일자부) 내용까지 중요한가요?
# 2026-02-08 15:51:17,214 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록·확정일자(확정일자) 했는데, 확정일자부(확정일자부) 내용까지 중요한가요?'
# 2026-02-08 15:51:17,823 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:18,945 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:19,979 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:22,064 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:22,067 - rag_module - INFO - 📌 Rerank selected=2 (threshold=0.22)
# 2026-02-08 15:51:22,068 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:23,981 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:26,234 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:26,236 - rag_module - INFO - 🔄 표준화된 질문: 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# 변경된 질문:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# ※ 참고: '전세사기'는 용어 사전에 '전세피해'로 직접 매핑되지 않았으나, 문맥상 '권리리스크'로 대체 가능한 것으로 판단하였습니다. 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다.
#
# (최종 출력 시 위 참고 문구 제외)
#
# **최종 출력:**
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
# 2026-02-08 15:51:26,237 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# 변경된 질문:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# ※ 참고: '전세사기'는 용어 사전에 '전세피해'로 직접 매핑되지 않았으나, 문맥상 '권리리스크'로 대체 가능한 것으로 판단하였습니다. 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다.
#
# (최종 출력 시 위 참고 문구 제외)
#
# **최종 출력:**
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?'
# 2026-02-08 15:51:26,747 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:27,581 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:28,446 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:30,243 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:30,246 - rag_module - INFO - 📌 Rerank selected=18 (threshold=0.22)
# 2026-02-08 15:51:30,247 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:33,273 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:33,875 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:33,877 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
# 2026-02-08 15:51:33,877 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?'
# 2026-02-08 15:51:34,365 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:36,879 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:39,282 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:43,072 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:43,075 - rag_module - INFO - 📌 Rerank selected=10 (threshold=0.24)
# 2026-02-08 15:51:43,084 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:45,778 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:46,478 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:46,481 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?
# 2026-02-08 15:51:46,481 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?'
# 2026-02-08 15:51:47,256 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:48,157 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:49,013 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:51,181 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:51,184 - rag_module - INFO - 📌 Rerank selected=9 (threshold=0.24)
# 2026-02-08 15:51:51,184 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:51:54,559 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:54,995 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:51:54,998 - rag_module - INFO - 🔄 표준화된 질문: 임대차계약증서에 1년이라고 기재되어 있으면, 1년 경과하면 무조건 주택의인도를 해야 하나요?
# 2026-02-08 15:51:54,999 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대차계약증서에 1년이라고 기재되어 있으면, 1년 경과하면 무조건 주택의인도를 해야 하나요?'
# 2026-02-08 15:51:55,720 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:56,658 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:57,540 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:51:59,699 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:51:59,701 - rag_module - INFO - 📌 Rerank selected=2 (threshold=0.24)
# 2026-02-08 15:51:59,702 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:02,118 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:02,938 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:02,940 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?
# 2026-02-08 15:52:02,941 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?'
# 2026-02-08 15:52:03,654 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:04,578 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:05,336 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:06,937 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:06,940 - rag_module - INFO - 📌 Rerank selected=5 (threshold=0.24)
# 2026-02-08 15:52:06,941 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:09,139 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:09,699 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:09,701 - rag_module - INFO - 🔄 표준화된 질문: 경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?
# 2026-02-08 15:52:09,702 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?'
# 2026-02-08 15:52:10,132 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:10,875 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:11,736 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:14,008 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:14,011 - rag_module - INFO - 📌 Rerank selected=6 (threshold=0.24)
# 2026-02-08 15:52:14,012 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:16,692 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:17,239 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:17,241 - rag_module - INFO - 🔄 표준화된 질문: 계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?
# 2026-02-08 15:52:17,242 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?'
# 2026-02-08 15:52:17,836 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:18,894 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:20,032 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:22,019 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:22,022 - rag_module - INFO - 📌 Rerank selected=2 (threshold=0.24)
# 2026-02-08 15:52:22,023 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:24,132 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:26,140 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:26,142 - rag_module - INFO - 🔄 표준화된 질문: 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
# (※ 참고: "묵시적갱신"은 용어 사전에 명시된 대로 "묵시적갱신"으로 유지되며, "이사"는 "주택의인도"로 변환됩니다. 다만, "살다"는 용어 사전에 없는 표현이므로 변환하지 않습니다.)
#
# 최종 출력:
# 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
#
# (※ 시스템 오류로 인해 "묵시적갱신"이 중복 표기된 점은 용어 사전 적용 시 발생할 수 있는 기술적 한계로, 실제 법률 표준어 변환 시 "묵시적갱신"만 사용하는 것이 원칙입니다.)
#
# **수정된 최종 답변**:
# 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
#
# (※ 재변환: "묵시적갱신"은 사전 매핑 시 "묵시적갱신 → 묵시적갱신"으로 동일하므로 괄호 생략 가능)
# **최종 출력**:
# 묵시적갱신으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
# 2026-02-08 15:52:26,143 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
# (※ 참고: "묵시적갱신"은 용어 사전에 명시된 대로 "묵시적갱신"으로 유지되며, "이사"는 "주택의인도"로 변환됩니다. 다만, "살다"는 용어 사전에 없는 표현이므로 변환하지 않습니다.)
#
# 최종 출력:
# 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
#
# (※ 시스템 오류로 인해 "묵시적갱신"이 중복 표기된 점은 용어 사전 적용 시 발생할 수 있는 기술적 한계로, 실제 법률 표준어 변환 시 "묵시적갱신"만 사용하는 것이 원칙입니다.)
#
# **수정된 최종 답변**:
# 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?
#
# (※ 재변환: "묵시적갱신"은 사전 매핑 시 "묵시적갱신 → 묵시적갱신"으로 동일하므로 괄호 생략 가능)
# **최종 출력**:
# 묵시적갱신으로 연장된 줄 모르고 살았는데, 이사(주택의인도) 가려면 언제까지 살아야 하나요?'
# 2026-02-08 15:52:26,634 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:27,526 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:28,698 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:30,761 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:30,763 - rag_module - INFO - 📌 Rerank selected=10 (threshold=0.24)
# 2026-02-08 15:52:30,764 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:32,746 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:33,462 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:33,464 - rag_module - INFO - 🔄 표준화된 질문: 신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)
# 2026-02-08 15:52:33,465 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)'
# 2026-02-08 15:52:34,152 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:35,180 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:36,115 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:38,155 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:38,159 - rag_module - INFO - 📌 Rerank selected=10 (threshold=0.24)
# 2026-02-08 15:52:38,160 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:41,099 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:41,970 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:41,972 - rag_module - INFO - 🔄 표준화된 질문: 주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요? (주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요?)
#
# ※ [용어 사전]에 '전입신고' → '주민등록' 매핑만 존재하며, '확정일자부'는 별도 정의되지 않아 원문 유지하였습니다.
# 2026-02-08 15:52:41,972 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요? (주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요?)
#
# ※ [용어 사전]에 '전입신고' → '주민등록' 매핑만 존재하며, '확정일자부'는 별도 정의되지 않아 원문 유지하였습니다.'
# 2026-02-08 15:52:42,687 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:43,782 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:44,654 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:46,501 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:46,503 - rag_module - INFO - 📌 Rerank selected=10 (threshold=0.24)
# 2026-02-08 15:52:46,505 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:48,921 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:49,533 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:52:49,535 - rag_module - INFO - 🔄 표준화된 질문: 전세피해(권리리스크) 피해자로 아직 공식 결정 전인데 경매절차 매각기일이 잡혔습니다. 이 경우에도 경매절차를 멈출 수 있는 방법이 있나요?
# 2026-02-08 15:52:49,535 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세피해(권리리스크) 피해자로 아직 공식 결정 전인데 경매절차 매각기일이 잡혔습니다. 이 경우에도 경매절차를 멈출 수 있는 방법이 있나요?'
# 2026-02-08 15:52:50,008 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:50,720 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:51,428 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-08 15:52:53,218 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-08 15:52:53,221 - rag_module - INFO - 📌 Rerank selected=4 (threshold=0.24)
# 2026-02-08 15:52:53,222 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-08 15:52:56,670 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# ✅ BASE_SAMPLES: 10
# ✅ EXP_SAMPLES : 10
#                                question  \
# 0  조정에서 합의했는데 집주인이 안 지켜요. 이거 강제할 수 있나요?
#
#                                               answer  \
# 0  A. 한 줄 결론  \n- **강제집행이 가능합니다.** 주택임대차보호법 제30조에...
#
#                                             contexts  \
# 0  [① 임대인이 임대차기간이 끝나기 6개월 전부터 2개월 전까지의 기간에 임차인에게 ...
#
#                                         ground_truth
# 0  네, 강제할 수 있습니다.\n주택임대차보호법 제27조에 따르면,\n 제26조제4항 ...

# %% [markdown]
# ## 6) RAGAS evaluation (prepared cell)
#
# - Creates per-sample detail dataframe (when supported by your RAGAS version)
# - Creates summary dataframe (mean over samples)
# - Keeps timing metrics

# %%
# ============================================================
# RAGAS compare + clean saving (ragas==0.3.2 compatible)
# FIXES:
#  1) detail.csv에서 _trace 제거 (trace는 trace.jsonl로만)
#  2) samples에 run_tag를 미리 주입해서 trace.jsonl에 태그가 남도록
#  3) ground_truths=[...] 안전장치 추가 (버전/환경 호환성↑)
#  4) samples/detail 컬럼 충돌 방지(가능한 한 안전하게 merge)
# ============================================================

import time, json, re
from pathlib import Path
from datetime import datetime
import os

import pandas as pd
from datasets import Dataset

from ragas import evaluate
from ragas.llms import llm_factory

# ----------------------------
# LLM + METRICS (ragas 0.3.2)
# ----------------------------

from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get("UPSTAGE_API_KEY"),
    base_url=os.environ.get("UPSTAGE_BASE_URL", "https://api.upstage.ai/v1/solar"),
)
if not os.environ.get("UPSTAGE_API_KEY"):
    raise EnvironmentError("UPSTAGE_API_KEY가 설정되어 있지 않습니다. 예: setx UPSTAGE_API_KEY \"...\"")
# llm = llm_factory("solar-pro2", client=client)
llm = llm_factory("solar-pro2")

# ----------------------------
# EMBEDDINGS (for AnswerRelevancy)
# ----------------------------
try:
    from langchain_openai import OpenAIEmbeddings
except Exception as e:
    raise ImportError("langchain-openai가 필요합니다. 설치: pip install langchain-openai") from e

lc_embeddings = OpenAIEmbeddings(
    model=os.environ.get("EMBEDDING_MODEL", "solar-embedding-1-large-passage"),
    api_key=os.environ.get("UPSTAGE_API_KEY"),
    base_url=os.environ.get("UPSTAGE_BASE_URL", "https://api.upstage.ai/v1/solar"),
)
from ragas.embeddings import LangchainEmbeddingsWrapper
embeddings = LangchainEmbeddingsWrapper(lc_embeddings)
# llm = llm_factory("solar-pro2", client=client)

def build_metrics_032():
    from ragas.metrics import context_precision, context_recall, faithfulness
    metrics = [context_precision, context_recall, faithfulness]
    # answer_relevancy는 환경에 따라 없을 수 있어 optional
    try:
        from ragas.metrics import answer_relevancy
        metrics.append(answer_relevancy)
    except ImportError:
        pass
    return metrics

METRICS = build_metrics_032()
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])

# ----------------------------
# utils
# ----------------------------
def _json_safe(obj):
    """Make config/meta safe to dump to json."""
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

def _next_run_dir(project_root: Path, prefix: str):
    runs_root = Path(project_root) / "results" / "ragas_runs"
    runs_root.mkdir(parents=True, exist_ok=True)

    pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
    nums = []
    for p in runs_root.iterdir():
        if p.is_dir():
            m = pat.match(p.name)
            if m:
                nums.append(int(m.group(1)))
    next_idx = (max(nums) + 1) if nums else 1

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = runs_root / f"{prefix}_{next_idx:04d}_{ts}"
    run_dir.mkdir(parents=True, exist_ok=False)
    return run_dir, next_idx, ts

def _strip_trace(samples):
    """detail.csv에는 _trace를 넣지 않기(파일 폭발 방지)."""
    out = []
    for s in samples:
        if isinstance(s, dict):
            out.append({k: v for k, v in s.items() if k != "_trace"})
        else:
            out.append(s)
    return out

# ----------------------------
# core eval
# ----------------------------
def eval_ragas_with_details(samples, run_tag: str):
    # ✅ samples에 run_tag를 미리 주입 (trace.jsonl에서 태그 유지)
    for s in samples:
        if isinstance(s, dict):
            s["run_tag"] = run_tag
            # ✅ 안전장치: ground_truths도 함께
            if "ground_truths" not in s:
                gt = s.get("ground_truth") or ""
                s["ground_truths"] = [gt] if isinstance(gt, str) else (gt or [])

    ds = Dataset.from_list(samples)

    t0 = time.time()
    res = evaluate(dataset=ds, metrics=METRICS, llm=llm, embeddings=embeddings)  # ✅ 0.3.2 안전 패턴
    eval_sec = time.time() - t0

    t1 = time.time()
    detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
    to_pandas_sec = time.time() - t1

    # ✅ detail에는 _trace 제외
    samples_df = pd.DataFrame(_strip_trace(samples))

    # merge per-sample metrics back onto samples (길이 동일할 때만)
    if len(detail_df) == len(samples_df) and len(detail_df) > 0:
        # 충돌 컬럼 방지: detail_df의 컬럼이 samples_df에 이미 있으면 prefix
        overlap = set(samples_df.columns) & set(detail_df.columns)
        if overlap:
            detail_df = detail_df.rename(columns={c: f"metric__{c}" for c in overlap})

        out_detail = pd.concat(
            [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
            axis=1
        )
    else:
        out_detail = samples_df.copy()

    out_detail["eval_seconds"] = round(eval_sec, 3)
    out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

    # summary (mean of numeric metric columns if available)
    summary = {}
    if len(detail_df) > 0:
        summary = detail_df.mean(numeric_only=True).to_dict()
    elif isinstance(res, dict):
        summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

    summary["run_tag"] = run_tag
    summary["eval_seconds"] = round(eval_sec, 3)
    summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

    return res, out_detail, pd.DataFrame([summary])

# ----------------------------
# compare + save (clean)
# ----------------------------
def run_compare_and_save(
    base_samples,
    exp_samples,
    project_root: Path,
    prefix="ragas_compare",
    base_cfg=None,
    exp_cfg=None,
):
    # --- sanity ---
    print(f"✅ base_samples: {len(base_samples)} | exp_samples: {len(exp_samples)}")

    base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
    exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

    summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
    detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

    run_dir, run_id, ts = _next_run_dir(project_root, prefix)

    out_summary = run_dir / "summary.csv"
    out_detail  = run_dir / "detail.csv"
    out_meta    = run_dir / "meta.json"
    out_config  = run_dir / "config.json"
    out_base_in = run_dir / "samples_base.jsonl"
    out_exp_in  = run_dir / "samples_exp.jsonl"
    out_trace   = run_dir / "trace.jsonl"

    summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
    detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

    # config snapshot (best-effort)
    cfg_payload = {
        "base_cfg": _json_safe(base_cfg) if base_cfg is not None else None,
        "exp_cfg":  _json_safe(exp_cfg)  if exp_cfg  is not None else None,
        "llm": {"model": "solar-pro2"},
        "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
        "created_at": datetime.now().isoformat(),
    }
    _write_json(out_config, cfg_payload)

    # input snapshots (원본 유지: _trace 포함)
    _write_jsonl(out_base_in, base_samples)
    _write_jsonl(out_exp_in,  exp_samples)

    # trace snapshot (best-effort) - samples의 _trace만 모아서 저장
    trace_rows = []
    for s in list(base_samples) + list(exp_samples):
        if isinstance(s, dict) and ("_trace" in s) and (s.get("_trace") is not None):
            trace_rows.append({
                "run_tag": s.get("run_tag"),
                "question": s.get("question"),
                "_trace": s.get("_trace"),
            })

    # trace가 아예 없으면 최소 정보라도 남김
    if not trace_rows:
        cols = [c for c in ["run_tag", "question", "eval_seconds"] if c in detail_df.columns]
        trace_rows = detail_df[cols].to_dict(orient="records") if cols else []

    _write_jsonl(out_trace, trace_rows)

    meta = {
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "ragas_version": "0.3.2",
        "run_id": run_id,
        "timestamp": ts,
        "run_dir": str(run_dir),
        "prefix": prefix,
        "n_base_samples": len(base_samples),
        "n_exp_samples": len(exp_samples),
        "saved": {
            "summary": str(out_summary),
            "detail": str(out_detail),
            "meta": str(out_meta),
            "config": str(out_config),
            "samples_base": str(out_base_in),
            "samples_exp": str(out_exp_in),
            "trace": str(out_trace),
        },
    }
    _write_json(out_meta, meta)

    print(f"✅ Saved to: {run_dir}")
    print(f"   - summary: {out_summary.name}")
    print(f"   - detail : {out_detail.name}")
    print(f"   - meta   : {out_meta.name}")
    print(f"   - config : {out_config.name}")
    print(f"   - inputs : {out_base_in.name}, {out_exp_in.name}")
    print(f"   - trace  : {out_trace.name}")

    return {
        "base_res": base_res,
        "exp_res": exp_res,
        "summary_df": summary_df,
        "detail_df": detail_df,
        "run_dir": run_dir,
        "out_summary": out_summary,
        "out_detail": out_detail,
        "out_meta": out_meta,
        "out_config": out_config,
        "out_samples_base": out_base_in,
        "out_samples_exp": out_exp_in,
        "out_trace": out_trace,
        "run_id": run_id,
    }

# ============================
# USAGE (예시)
# ============================
# result = run_compare_and_save(
#     base_samples=BASE_SAMPLES,
#     exp_samples=EXP_SAMPLES,
#     project_root=PROJECT_ROOT,
#     prefix="ragas_compare",
#     base_cfg=base_cfg,
#     exp_cfg=exp_cfg,
# )
# display(result["summary_df"])
# display(result["detail_df"].head(3))
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']

# %% [markdown]
# ## 7) Run + compare + save

# %%
# ============================================================
# One-cell: RAGAS compare + save (+ delta outputs + dataset fingerprint)
# Adds:
#  - delta_summary.csv
#  - delta_detail.csv
#  - top_regressions.csv
#  - top_improvements.csv
#  - meta.json: testset fingerprint (path/lines/sha1) if TESTSET_JSONL exists
# ============================================================

import time, re, json, hashlib
from pathlib import Path
from datetime import datetime
import os

import pandas as pd
from datasets import Dataset

from openai import OpenAI
from ragas import evaluate
from ragas.llms import llm_factory


# ----------------------------
# LLM (non-deprecated)
# ----------------------------
client = OpenAI(
    api_key=os.environ.get("UPSTAGE_API_KEY"),
    base_url=os.environ.get("UPSTAGE_BASE_URL", "https://api.upstage.ai/v1/solar"),
)
if not os.environ.get("UPSTAGE_API_KEY"):
    raise EnvironmentError("UPSTAGE_API_KEY가 설정되어 있지 않습니다. 예: setx UPSTAGE_API_KEY \"...\"")
# llm = llm_factory("solar-pro2", client=client)  # ✅ Upstage Solar Pro2
llm = llm_factory("solar-pro2")  # ✅ Upstage Solar Pro2
# ----------------------------
# EMBEDDINGS (for AnswerRelevancy)
# ----------------------------
# RAGAS의 answer_relevancy는 embeddings가 필요할 수 있습니다.
# Upstage(OpenAI-compatible) embeddings endpoint를 사용합니다.
try:
    from langchain_openai import OpenAIEmbeddings
except Exception as e:
    raise ImportError(
        "langchain-openai가 필요합니다. 설치: pip install langchain-openai"
    ) from e

lc_embeddings = OpenAIEmbeddings(
    model=os.environ.get("EMBEDDING_MODEL", "solar-embedding-1-large-passage"),
    api_key=os.environ.get("UPSTAGE_API_KEY"),
    base_url=os.environ.get("UPSTAGE_BASE_URL", "https://api.upstage.ai/v1/solar"),
)

# RAGAS는 embeddings 래퍼를 기대하는 경우가 있어 LangChain 래퍼로 감쌉니다.
from ragas.embeddings import LangchainEmbeddingsWrapper
embeddings = LangchainEmbeddingsWrapper(lc_embeddings)


# ----------------------------
# METRICS (version-tolerant)
# ----------------------------
def build_metrics():
    from ragas.metrics import context_precision, context_recall, faithfulness
    metrics = [context_precision, context_recall, faithfulness]
    try:
        from ragas.metrics import answer_relevancy
        metrics.append(answer_relevancy)
    except ImportError:
        pass
    return metrics

METRICS = build_metrics()
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])


# ----------------------------
# JSON helpers (safe)
# ----------------------------
def _json_safe(obj):
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

def _df_to_jsonl_rows(df, prefer_cols):
    cols = [c for c in prefer_cols if c in df.columns]
    if cols:
        df = df[cols].copy()
    return df.to_dict(orient="records"), cols


# ----------------------------
# dataset fingerprint helpers
# ----------------------------
def _file_sha1(path: Path, chunk_size=1024 * 1024) -> str:
    h = hashlib.sha1()
    with path.open("rb") as f:
        while True:
            b = f.read(chunk_size)
            if not b:
                break
            h.update(b)
    return h.hexdigest()

def _count_jsonl_lines(path: Path) -> int:
    n = 0
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                n += 1
    return n


# ----------------------------
# core: eval + detail/summary frames
# ----------------------------
def eval_ragas_with_details(samples, run_tag: str):
    ds = Dataset.from_list(samples)

    t0 = time.time()
    res = evaluate(dataset=ds, metrics=METRICS, llm=llm, embeddings=embeddings)  # ✅ llm/embeddings
    eval_sec = time.time() - t0

    t1 = time.time()
    detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
    to_pandas_sec = time.time() - t1

    samples_df = pd.DataFrame(samples)

    # merge
    if len(detail_df) == len(samples_df) and len(detail_df) > 0:
        out_detail = pd.concat(
            [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
            axis=1
        )
    else:
        out_detail = samples_df.copy()

    out_detail["run_tag"] = run_tag
    out_detail["eval_seconds"] = round(eval_sec, 3)
    out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

    # summary
    summary = {}
    if len(detail_df) > 0:
        summary = detail_df.mean(numeric_only=True).to_dict()
    elif isinstance(res, dict):
        summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

    summary["run_tag"] = run_tag
    summary["eval_seconds"] = round(eval_sec, 3)
    summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

    return res, out_detail, pd.DataFrame([summary])


# ----------------------------
# run dir allocator
# ----------------------------
def _next_run_dir(project_root: Path, prefix: str):
    runs_root = Path(project_root) / "results" / "ragas_runs"
    runs_root.mkdir(parents=True, exist_ok=True)

    pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
    nums = []
    for p in runs_root.iterdir():
        if p.is_dir():
            m = pat.match(p.name)
            if m:
                nums.append(int(m.group(1)))
    next_id = (max(nums) + 1) if nums else 1

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = runs_root / f"{prefix}_{next_id:04d}_{ts}"
    run_dir.mkdir(parents=True, exist_ok=False)
    return run_dir, next_id, ts


# ----------------------------
# delta builders
# ----------------------------
def _pick_question_col(df: pd.DataFrame) -> str:
    for c in ["question", "normalized_question", "normalized_query", "query"]:
        if c in df.columns:
            return c
    return ""

def _ensure_question_id(df: pd.DataFrame) -> pd.DataFrame:
    # prefer an existing stable id
    for c in ["question_id", "id", "sample_id"]:
        if c in df.columns:
            df = df.copy()
            df["__qid__"] = df[c].astype(str)
            return df
    # fallback: hash question text
    qcol = _pick_question_col(df)
    df = df.copy()
    if qcol:
        def _h(x: str) -> str:
            s = (x or "").strip().encode("utf-8")
            return hashlib.sha1(s).hexdigest()[:12]
        df["__qid__"] = df[qcol].astype(str).map(_h)
    else:
        df["__qid__"] = [f"row{i:04d}" for i in range(len(df))]
    return df

def _metric_cols(df: pd.DataFrame) -> list:
    # heuristic: numeric columns from ragas result + common metric names
    prefer = [
        "context_precision", "context_recall", "faithfulness", "answer_relevancy",
        "ContextPrecision", "ContextRecall", "Faithfulness", "AnswerRelevancy",
    ]
    cols = [c for c in prefer if c in df.columns]
    if cols:
        return cols

    # fallback: any numeric columns that are not obvious non-metrics
    exclude = set(["eval_seconds", "to_pandas_seconds"])
    num_cols = []
    for c in df.columns:
        if c in exclude:
            continue
        if pd.api.types.is_numeric_dtype(df[c]):
            num_cols.append(c)
    return num_cols


def _make_delta_summary(summary_df: pd.DataFrame) -> pd.DataFrame:
    # summary_df has rows: baseline/experiment
    metric_cols = [c for c in summary_df.columns if c not in ["run_tag"]]
    base = summary_df[summary_df["run_tag"] == "baseline"].iloc[0].to_dict()
    exp  = summary_df[summary_df["run_tag"] == "experiment"].iloc[0].to_dict()

    rows = []
    for c in metric_cols:
        if c == "run_tag":
            continue
        b = base.get(c)
        e = exp.get(c)
        if isinstance(b, (int, float)) and isinstance(e, (int, float)):
            rows.append({"metric": c, "baseline": float(b), "experiment": float(e), "delta": float(e - b)})
        else:
            # keep non-numeric too
            rows.append({"metric": c, "baseline": b, "experiment": e, "delta": None})
    return pd.DataFrame(rows)


def _make_delta_detail(detail_df: pd.DataFrame) -> pd.DataFrame:
    df = _ensure_question_id(detail_df)

    base = df[df["run_tag"] == "baseline"].copy()
    exp  = df[df["run_tag"] == "experiment"].copy()

    # --- choose question column ---
    qcol = _pick_question_col(df)

    # --- metric columns ---
    mcols = _metric_cols(df)

    # --- info columns to keep (these overlap across base/exp) ---
    info_cols = ["__qid__"]
    if qcol:
        info_cols.append(qcol)
    for c in ["ground_truth", "reference", "answer", "contexts"]:
        if c in df.columns:
            info_cols.append(c)

    # --- select + rename (so no overlap) ---
    base_small = base[info_cols + mcols].copy()
    exp_small  = exp[info_cols + mcols].copy()

    rename_base = {c: f"{c}_base" for c in info_cols if c != "__qid__"}
    rename_exp  = {c: f"{c}_exp"  for c in info_cols if c != "__qid__"}
    rename_base.update({c: f"{c}_base" for c in mcols})
    rename_exp.update({c: f"{c}_exp"  for c in mcols})

    base_small = base_small.rename(columns=rename_base)
    exp_small  = exp_small.rename(columns=rename_exp)

    # --- merge safely ---
    merged = exp_small.merge(base_small, on="__qid__", how="outer")

    # --- compute deltas ---
    for c in mcols:
        cb = f"{c}_base"
        ce = f"{c}_exp"
        if cb in merged.columns and ce in merged.columns:
            merged[f"{c}_delta"] = merged[ce] - merged[cb]

    # --- convenience: make a unified question column (prefer exp, fallback base) ---
    if qcol:
        qe = f"{qcol}_exp"
        qb = f"{qcol}_base"
        if qe in merged.columns or qb in merged.columns:
            merged[qcol] = None
            if qe in merged.columns:
                merged[qcol] = merged[qe]
            if qb in merged.columns:
                merged[qcol] = merged[qcol].fillna(merged[qb])

    # --- order columns nicely ---
    ordered = ["__qid__"]
    if qcol and qcol in merged.columns:
        ordered.append(qcol)

    # keep references (unified view is optional; we keep exp/base separately)
    for c in ["ground_truth", "reference"]:
        # add unified if you want; here we keep exp/base columns only
        pass

    # metrics grouped
    for c in mcols:
        for suf in ["_base", "_exp", "_delta"]:
            col = f"{c}{suf}"
            if col in merged.columns:
                ordered.append(col)

    # then common info columns (exp/base)
    tail_info = []
    for c in ["ground_truth", "reference", "answer", "contexts"]:
        ce, cb = f"{c}_exp", f"{c}_base"
        if ce in merged.columns:
            tail_info.append(ce)
        if cb in merged.columns:
            tail_info.append(cb)

    remaining = [c for c in merged.columns if c not in ordered and c not in tail_info]
    return merged[ordered + remaining + tail_info].copy()



def _make_top_changes(delta_detail_df: pd.DataFrame, top_k=10) -> tuple[pd.DataFrame, pd.DataFrame, str]:
    # choose primary metric for sorting
    candidates = [
        "answer_relevancy_delta", "AnswerRelevancy_delta",
        "faithfulness_delta", "Faithfulness_delta",
        "context_precision_delta", "ContextPrecision_delta",
        "context_recall_delta", "ContextRecall_delta",
    ]
    sort_col = next((c for c in candidates if c in delta_detail_df.columns), None)
    if sort_col is None:
        # fallback: first *_delta numeric column
        delta_cols = [c for c in delta_detail_df.columns if c.endswith("_delta") and pd.api.types.is_numeric_dtype(delta_detail_df[c])]
        sort_col = delta_cols[0] if delta_cols else ""

    if not sort_col:
        # nothing to rank
        return pd.DataFrame(), pd.DataFrame(), ""

    # pick minimal view columns
    qcol = _pick_question_col(delta_detail_df)
    view_cols = [c for c in ["__qid__", qcol, sort_col] if c and c in delta_detail_df.columns]
    # add also base/exp of that metric if present
    base_col = sort_col.replace("_delta", "_base")
    exp_col  = sort_col.replace("_delta", "_exp")
    for c in [base_col, exp_col]:
        if c in delta_detail_df.columns and c not in view_cols:
            view_cols.append(c)

    regress = delta_detail_df.sort_values(sort_col, ascending=True).head(top_k)[view_cols].copy()
    improve = delta_detail_df.sort_values(sort_col, ascending=False).head(top_k)[view_cols].copy()
    return regress, improve, sort_col


# ----------------------------
# main: compare + save (csv/json + optional snapshots)
# ----------------------------
def run_compare_and_save_all(
    base_samples,
    exp_samples,
    project_root: Path,
    prefix="ragas_compare",
    save_snapshots=True,
    save_config=True,
    save_samples_jsonl=True,
    save_trace_jsonl=True,
    trace_cols_priority=None,
    save_delta_outputs=True,
    top_k=10,
):
    # 1) evaluate
    base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
    exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

    summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
    detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

    # 2) run dir
    run_dir, run_id, ts = _next_run_dir(project_root, prefix)

    # 3) basic outputs
    out_summary = run_dir / "summary.csv"
    out_detail  = run_dir / "detail.csv"
    out_meta    = run_dir / "meta.json"

    summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
    detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

    # --- dataset fingerprint (optional) ---
    testset_info = None
    if "TESTSET_JSONL" in globals():
        p = Path(globals()["TESTSET_JSONL"])
        if p.exists():
            testset_info = {
                "testset_path": str(p),
                "testset_lines": _count_jsonl_lines(p),
                "testset_sha1": _file_sha1(p),
            }

    meta = {
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "run_id": run_id,
        "timestamp": ts,
        "run_dir": str(run_dir),
        "prefix": prefix,
        "n_base_samples": len(base_samples),
        "n_exp_samples": len(exp_samples),
        "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
        "llm": {"model": "solar-pro2"},
        "testset": testset_info,
    }
    _write_json(out_meta, meta)

    # 3-1) DELTA outputs (⭐️ NEW)
    extra = {}
    if save_delta_outputs:
        # delta_summary
        delta_summary_df = _make_delta_summary(summary_df)
        out_delta_summary = run_dir / "delta_summary.csv"
        delta_summary_df.to_csv(out_delta_summary, index=False, encoding="utf-8-sig")
        extra["out_delta_summary"] = str(out_delta_summary)

        # delta_detail
        delta_detail_df = _make_delta_detail(detail_df)
        out_delta_detail = run_dir / "delta_detail.csv"
        delta_detail_df.to_csv(out_delta_detail, index=False, encoding="utf-8-sig")
        extra["out_delta_detail"] = str(out_delta_detail)

        # top changes (regressions/improvements)
        top_regress, top_improve, sort_col = _make_top_changes(delta_detail_df, top_k=top_k)
        out_top_regress = run_dir / "top_regressions.csv"
        out_top_improve = run_dir / "top_improvements.csv"
        top_regress.to_csv(out_top_regress, index=False, encoding="utf-8-sig")
        top_improve.to_csv(out_top_improve, index=False, encoding="utf-8-sig")
        extra["out_top_regressions"] = str(out_top_regress)
        extra["out_top_improvements"] = str(out_top_improve)
        extra["top_rank_metric"] = sort_col

    # 4) optional snapshots
    if save_snapshots:
        # 4-1) config.json
        if save_config:
            cfg_payload = {
                "created_at": datetime.now().isoformat(),
                "llm": {"model": "solar-pro2"},
                "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
                "base_cfg": _json_safe(globals().get("base_cfg")) if "base_cfg" in globals() else None,
                "exp_cfg":  _json_safe(globals().get("exp_cfg"))  if "exp_cfg"  in globals() else None,
            }
            out_config = run_dir / "config.json"
            _write_json(out_config, cfg_payload)
            extra["out_config"] = str(out_config)

        # 4-2) input samples jsonl
        if save_samples_jsonl:
            out_samples_base = run_dir / "samples_base.jsonl"
            out_samples_exp  = run_dir / "samples_exp.jsonl"
            _write_jsonl(out_samples_base, base_samples)
            _write_jsonl(out_samples_exp,  exp_samples)
            extra["out_samples_base"] = str(out_samples_base)
            extra["out_samples_exp"]  = str(out_samples_exp)

        # 4-3) trace jsonl (from detail_df)
        if save_trace_jsonl:
            if trace_cols_priority is None:
                trace_cols_priority = [
                    "id", "sample_id", "__qid__",
                    "question", "normalized_question", "normalized_query", "query",
                    "answer", "ground_truth", "reference",
                    "contexts",
                    "_trace",
                    "retrieved_doc_ids", "retrieved_docs", "retrieval_scores",
                    "rerank_selected_ids", "rerank_scores",
                    "final_context_ids", "final_contexts",
                    "latency_ms", "latency_sec",
                    "run_tag",
                ]
            trace_rows, used_cols = _df_to_jsonl_rows(detail_df, trace_cols_priority)
            out_trace = run_dir / "trace.jsonl"
            _write_jsonl(out_trace, trace_rows)
            extra["out_trace"] = str(out_trace)
            extra["trace_cols_used"] = used_cols

    return {
        "base_res": base_res,
        "exp_res": exp_res,
        "summary_df": summary_df,
        "detail_df": detail_df,
        "run_dir": str(run_dir),
        "out_summary": str(out_summary),
        "out_detail": str(out_detail),
        "out_meta": str(out_meta),
        **extra,
    }


# ----------------------------
# RUN
# ----------------------------
result = run_compare_and_save_all(
    base_samples=BASE_SAMPLES,
    exp_samples=EXP_SAMPLES,
    project_root=PROJECT_ROOT,
    prefix="ragas_compare",
    save_snapshots=True,
    save_config=True,
    save_samples_jsonl=True,
    save_trace_jsonl=True,
    save_delta_outputs=True,  # ✅ NEW
    top_k=10,                 # ✅ NEW
)

print("✅ run_dir:", result["run_dir"])
print("✅ saved:", result["out_summary"], result["out_detail"], result["out_meta"])

# NEW delta outputs
if "out_delta_summary" in result:
    print("✅ delta saved:", result["out_delta_summary"], result.get("out_delta_detail"))
    print("✅ top changes metric:", result.get("top_rank_metric"))
    print("✅ top regressions:", result.get("out_top_regressions"))
    print("✅ top improvements:", result.get("out_top_improvements"))

# snapshots
if "out_config" in result:
    print("✅ extra saved config :", result["out_config"])
if "out_samples_base" in result:
    print("✅ extra saved samples:", result["out_samples_base"], "and", result.get("out_samples_exp"))
if "out_trace" in result:
    print("✅ extra saved trace  :", result["out_trace"])
    print("✅ trace columns used :", result.get("trace_cols_used"))
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# 2026-02-08 15:53:01,357 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,364 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,393 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,438 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,441 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,665 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,667 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,715 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,717 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,775 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:53:01,777 - ragas.executor - ERROR - Exception raised in Job[3]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:53:01,778 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,779 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,817 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:53:01,851 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:53:01,852 - ragas.executor - ERROR - Exception raised in Job[7]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:53:01,853 - ragas.executor - ERROR - Exception raised in Job[11]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:53:01,854 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,855 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:01,897 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:53:01,899 - ragas.executor - ERROR - Exception raised in Job[15]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:53:01,900 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,240 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,518 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,681 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,733 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,738 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:02,789 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:53:02,790 - ragas.executor - ERROR - Exception raised in Job[19]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:53:02,974 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,034 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,254 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,321 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,407 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,410 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,671 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,707 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:03,709 - openai._base_client - INFO - Retrying request to /chat/completions in 0.479963 seconds
# 2026-02-08 15:53:03,785 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,819 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:03,820 - openai._base_client - INFO - Retrying request to /chat/completions in 0.484470 seconds
# 2026-02-08 15:53:03,846 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,883 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:03,885 - openai._base_client - INFO - Retrying request to /chat/completions in 0.468734 seconds
# 2026-02-08 15:53:03,904 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:03,939 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:03,941 - openai._base_client - INFO - Retrying request to /chat/completions in 0.418777 seconds
# 2026-02-08 15:53:04,218 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,229 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,231 - openai._base_client - INFO - Retrying request to /chat/completions in 0.913342 seconds
# 2026-02-08 15:53:04,252 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,253 - openai._base_client - INFO - Retrying request to /chat/completions in 0.404963 seconds
# 2026-02-08 15:53:04,335 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,337 - openai._base_client - INFO - Retrying request to /chat/completions in 0.967108 seconds
# 2026-02-08 15:53:04,367 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,388 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,390 - openai._base_client - INFO - Retrying request to /chat/completions in 0.852186 seconds
# 2026-02-08 15:53:04,391 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,392 - openai._base_client - INFO - Retrying request to /chat/completions in 0.791874 seconds
# 2026-02-08 15:53:04,399 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,401 - openai._base_client - INFO - Retrying request to /chat/completions in 0.415726 seconds
# 2026-02-08 15:53:04,533 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,568 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,570 - openai._base_client - INFO - Retrying request to /chat/completions in 0.426949 seconds
# 2026-02-08 15:53:04,694 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,695 - openai._base_client - INFO - Retrying request to /chat/completions in 0.830814 seconds
# 2026-02-08 15:53:04,723 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,738 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,762 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,764 - openai._base_client - INFO - Retrying request to /chat/completions in 0.468597 seconds
# 2026-02-08 15:53:04,772 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,774 - openai._base_client - INFO - Retrying request to /chat/completions in 0.484175 seconds
# 2026-02-08 15:53:04,849 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,850 - openai._base_client - INFO - Retrying request to /chat/completions in 0.921562 seconds
# 2026-02-08 15:53:04,886 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:04,921 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:04,923 - openai._base_client - INFO - Retrying request to /chat/completions in 0.488079 seconds
# 2026-02-08 15:53:05,087 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,089 - openai._base_client - INFO - Retrying request to /chat/completions in 0.957612 seconds
# 2026-02-08 15:53:05,192 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,249 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,261 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,262 - openai._base_client - INFO - Retrying request to /chat/completions in 0.417742 seconds
# 2026-02-08 15:53:05,301 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,304 - openai._base_client - INFO - Retrying request to /chat/completions in 0.905152 seconds
# 2026-02-08 15:53:05,305 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,313 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,314 - openai._base_client - INFO - Retrying request to /chat/completions in 0.884412 seconds
# 2026-02-08 15:53:05,339 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:05,345 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,383 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,385 - openai._base_client - INFO - Retrying request to /chat/completions in 0.409902 seconds
# 2026-02-08 15:53:05,458 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,460 - openai._base_client - INFO - Retrying request to /chat/completions in 0.998225 seconds
# 2026-02-08 15:53:05,538 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,540 - openai._base_client - INFO - Retrying request to /chat/completions in 0.489108 seconds
# 2026-02-08 15:53:05,563 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,597 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,599 - openai._base_client - INFO - Retrying request to /chat/completions in 0.377946 seconds
# 2026-02-08 15:53:05,735 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,737 - openai._base_client - INFO - Retrying request to /chat/completions in 0.484154 seconds
# 2026-02-08 15:53:05,738 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,740 - openai._base_client - INFO - Retrying request to /chat/completions in 0.798771 seconds
# 2026-02-08 15:53:05,814 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,817 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:05,819 - openai._base_client - INFO - Retrying request to /chat/completions in 0.750367 seconds
# 2026-02-08 15:53:06,017 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,019 - openai._base_client - INFO - Retrying request to /chat/completions in 0.758026 seconds
# 2026-02-08 15:53:06,049 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,052 - openai._base_client - INFO - Retrying request to /chat/completions in 0.924799 seconds
# 2026-02-08 15:53:06,080 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,210 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:06,243 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,245 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,247 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,249 - openai._base_client - INFO - Retrying request to /chat/completions in 0.782689 seconds
# 2026-02-08 15:53:06,251 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,253 - openai._base_client - INFO - Retrying request to /chat/completions in 0.377446 seconds
# 2026-02-08 15:53:06,254 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,256 - openai._base_client - INFO - Retrying request to /chat/completions in 0.417912 seconds
# 2026-02-08 15:53:06,258 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,259 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,260 - openai._base_client - INFO - Retrying request to /chat/completions in 0.425466 seconds
# 2026-02-08 15:53:06,262 - openai._base_client - INFO - Retrying request to /chat/completions in 0.379307 seconds
# 2026-02-08 15:53:06,402 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:06,436 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,439 - openai._base_client - INFO - Retrying request to /chat/completions in 0.382790 seconds
# 2026-02-08 15:53:06,445 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,447 - openai._base_client - INFO - Retrying request to /chat/completions in 0.392598 seconds
# 2026-02-08 15:53:06,471 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,473 - openai._base_client - INFO - Retrying request to /chat/completions in 0.418012 seconds
# 2026-02-08 15:53:06,481 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,567 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,603 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,605 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,607 - openai._base_client - INFO - Retrying request to /chat/completions in 0.385906 seconds
# 2026-02-08 15:53:06,634 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,636 - openai._base_client - INFO - Retrying request to /chat/completions in 0.388543 seconds
# 2026-02-08 15:53:06,658 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,660 - openai._base_client - INFO - Retrying request to /chat/completions in 0.800434 seconds
# 2026-02-08 15:53:06,680 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,684 - openai._base_client - INFO - Retrying request to /chat/completions in 0.817193 seconds
# 2026-02-08 15:53:06,693 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,694 - openai._base_client - INFO - Retrying request to /chat/completions in 0.821591 seconds
# 2026-02-08 15:53:06,712 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,714 - openai._base_client - INFO - Retrying request to /chat/completions in 0.788074 seconds
# 2026-02-08 15:53:06,802 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,867 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,868 - openai._base_client - INFO - Retrying request to /chat/completions in 0.988213 seconds
# 2026-02-08 15:53:06,870 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,871 - openai._base_client - INFO - Retrying request to /chat/completions in 0.783350 seconds
# 2026-02-08 15:53:06,931 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:06,933 - openai._base_client - INFO - Retrying request to /chat/completions in 0.971394 seconds
# 2026-02-08 15:53:07,010 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,042 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,044 - openai._base_client - INFO - Retrying request to /chat/completions in 0.381113 seconds
# 2026-02-08 15:53:07,045 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,046 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,047 - openai._base_client - INFO - Retrying request to /chat/completions in 0.764089 seconds
# 2026-02-08 15:53:07,048 - openai._base_client - INFO - Retrying request to /chat/completions in 0.903642 seconds
# 2026-02-08 15:53:07,065 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,291 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:07,331 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,332 - openai._base_client - INFO - Retrying request to /chat/completions in 0.435341 seconds
# 2026-02-08 15:53:07,397 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,399 - openai._base_client - INFO - Retrying request to /chat/completions in 0.455270 seconds
# 2026-02-08 15:53:07,434 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,436 - openai._base_client - INFO - Retrying request to /chat/completions in 0.468451 seconds
# 2026-02-08 15:53:07,438 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,439 - openai._base_client - INFO - Retrying request to /chat/completions in 0.400776 seconds
# 2026-02-08 15:53:07,458 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,461 - openai._base_client - INFO - Retrying request to /chat/completions in 0.980849 seconds
# 2026-02-08 15:53:07,497 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,530 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,532 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,534 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,689 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,691 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,693 - openai._base_client - INFO - Retrying request to /chat/completions in 0.431402 seconds
# 2026-02-08 15:53:07,805 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,809 - openai._base_client - INFO - Retrying request to /chat/completions in 0.906616 seconds
# 2026-02-08 15:53:07,845 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,879 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,882 - openai._base_client - INFO - Retrying request to /chat/completions in 0.768000 seconds
# 2026-02-08 15:53:07,884 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,886 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,896 - openai._base_client - INFO - Retrying request to /chat/completions in 0.938856 seconds
# 2026-02-08 15:53:07,926 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,929 - openai._base_client - INFO - Retrying request to /chat/completions in 0.843441 seconds
# 2026-02-08 15:53:07,930 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,932 - openai._base_client - INFO - Retrying request to /chat/completions in 0.479002 seconds
# 2026-02-08 15:53:07,961 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:07,995 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,162 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,164 - openai._base_client - INFO - Retrying request to /chat/completions in 0.980359 seconds
# 2026-02-08 15:53:08,250 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,252 - openai._base_client - INFO - Retrying request to /chat/completions in 0.472235 seconds
# 2026-02-08 15:53:08,332 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,333 - openai._base_client - INFO - Retrying request to /chat/completions in 0.440779 seconds
# 2026-02-08 15:53:08,366 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,367 - openai._base_client - INFO - Retrying request to /chat/completions in 0.476420 seconds
# 2026-02-08 15:53:08,389 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,392 - openai._base_client - INFO - Retrying request to /chat/completions in 0.483718 seconds
# 2026-02-08 15:53:08,421 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,424 - openai._base_client - INFO - Retrying request to /chat/completions in 0.966236 seconds
# 2026-02-08 15:53:08,455 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,559 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,561 - openai._base_client - INFO - Retrying request to /chat/completions in 0.377930 seconds
# 2026-02-08 15:53:08,691 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,761 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,771 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,772 - openai._base_client - INFO - Retrying request to /chat/completions in 0.896776 seconds
# 2026-02-08 15:53:08,795 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,796 - openai._base_client - INFO - Retrying request to /chat/completions in 0.769797 seconds
# 2026-02-08 15:53:08,798 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,799 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,800 - openai._base_client - INFO - Retrying request to /chat/completions in 0.486633 seconds
# 2026-02-08 15:53:08,805 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,807 - openai._base_client - INFO - Retrying request to /chat/completions in 0.413207 seconds
# 2026-02-08 15:53:08,881 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:08,884 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,885 - openai._base_client - INFO - Retrying request to /chat/completions in 0.811234 seconds
# 2026-02-08 15:53:08,887 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,888 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,890 - openai._base_client - INFO - Retrying request to /chat/completions in 0.883558 seconds
# 2026-02-08 15:53:08,928 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,930 - openai._base_client - INFO - Retrying request to /chat/completions in 0.406214 seconds
# 2026-02-08 15:53:08,982 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,984 - openai._base_client - INFO - Retrying request to /chat/completions in 0.885429 seconds
# 2026-02-08 15:53:08,985 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:08,987 - openai._base_client - INFO - Retrying request to /chat/completions in 0.466825 seconds
# 2026-02-08 15:53:09,178 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,180 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,182 - openai._base_client - INFO - Retrying request to /chat/completions in 0.473285 seconds
# 2026-02-08 15:53:09,260 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,263 - openai._base_client - INFO - Retrying request to /chat/completions in 0.982402 seconds
# 2026-02-08 15:53:09,293 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,294 - openai._base_client - INFO - Retrying request to /chat/completions in 0.376951 seconds
# 2026-02-08 15:53:09,318 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,321 - openai._base_client - INFO - Retrying request to /chat/completions in 0.802329 seconds
# 2026-02-08 15:53:09,351 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,352 - openai._base_client - INFO - Retrying request to /chat/completions in 0.986731 seconds
# 2026-02-08 15:53:09,427 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,494 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,495 - openai._base_client - INFO - Retrying request to /chat/completions in 0.789732 seconds
# 2026-02-08 15:53:09,496 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,498 - openai._base_client - INFO - Retrying request to /chat/completions in 0.499387 seconds
# 2026-02-08 15:53:09,595 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,630 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,632 - openai._base_client - INFO - Retrying request to /chat/completions in 0.454487 seconds
# 2026-02-08 15:53:09,691 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,694 - openai._base_client - INFO - Retrying request to /chat/completions in 0.931186 seconds
# 2026-02-08 15:53:09,695 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,697 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,699 - openai._base_client - INFO - Retrying request to /chat/completions in 0.384924 seconds
# 2026-02-08 15:53:09,727 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,729 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,730 - openai._base_client - INFO - Retrying request to /chat/completions in 0.781494 seconds
# 2026-02-08 15:53:09,799 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,802 - openai._base_client - INFO - Retrying request to /chat/completions in 0.390679 seconds
# 2026-02-08 15:53:09,804 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,835 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:09,837 - openai._base_client - INFO - Retrying request to /chat/completions in 0.473766 seconds
# 2026-02-08 15:53:09,918 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,008 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,011 - openai._base_client - INFO - Retrying request to /chat/completions in 0.463790 seconds
# 2026-02-08 15:53:10,042 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,044 - openai._base_client - INFO - Retrying request to /chat/completions in 0.777168 seconds
# 2026-02-08 15:53:10,114 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,116 - openai._base_client - INFO - Retrying request to /chat/completions in 0.949300 seconds
# 2026-02-08 15:53:10,118 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,119 - openai._base_client - INFO - Retrying request to /chat/completions in 0.940197 seconds
# 2026-02-08 15:53:10,146 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,242 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,244 - openai._base_client - INFO - Retrying request to /chat/completions in 0.816685 seconds
# 2026-02-08 15:53:10,276 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,305 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,330 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,332 - openai._base_client - INFO - Retrying request to /chat/completions in 0.942455 seconds
# 2026-02-08 15:53:10,363 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,438 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,439 - openai._base_client - INFO - Retrying request to /chat/completions in 0.497634 seconds
# 2026-02-08 15:53:10,502 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,504 - openai._base_client - INFO - Retrying request to /chat/completions in 0.853682 seconds
# 2026-02-08 15:53:10,560 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,663 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,693 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:53:10,733 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,734 - openai._base_client - INFO - Retrying request to /chat/completions in 0.496094 seconds
# 2026-02-08 15:53:10,735 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,737 - openai._base_client - INFO - Retrying request to /chat/completions in 0.403722 seconds
# 2026-02-08 15:53:10,738 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,739 - openai._base_client - INFO - Retrying request to /chat/completions in 0.476592 seconds
# 2026-02-08 15:53:10,830 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,833 - openai._base_client - INFO - Retrying request to /chat/completions in 0.429727 seconds
# 2026-02-08 15:53:10,861 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,980 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,981 - openai._base_client - INFO - Retrying request to /chat/completions in 0.816243 seconds
# 2026-02-08 15:53:10,984 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:10,985 - openai._base_client - INFO - Retrying request to /chat/completions in 0.477757 seconds
# 2026-02-08 15:53:11,006 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,007 - openai._base_client - INFO - Retrying request to /chat/completions in 0.460408 seconds
# 2026-02-08 15:53:11,100 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,102 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,103 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,105 - openai._base_client - INFO - Retrying request to /chat/completions in 0.491715 seconds
# 2026-02-08 15:53:11,106 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,140 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,142 - openai._base_client - INFO - Retrying request to /chat/completions in 0.377868 seconds
# 2026-02-08 15:53:11,173 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,174 - openai._base_client - INFO - Retrying request to /chat/completions in 0.788042 seconds
# 2026-02-08 15:53:11,249 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,251 - openai._base_client - INFO - Retrying request to /chat/completions in 0.915504 seconds
# 2026-02-08 15:53:11,252 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,254 - openai._base_client - INFO - Retrying request to /chat/completions in 0.762995 seconds
# 2026-02-08 15:53:11,286 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,287 - openai._base_client - INFO - Retrying request to /chat/completions in 0.814646 seconds
# 2026-02-08 15:53:11,316 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,322 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,323 - openai._base_client - INFO - Retrying request to /chat/completions in 0.451248 seconds
# 2026-02-08 15:53:11,411 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,413 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,414 - openai._base_client - INFO - Retrying request to /chat/completions in 0.486540 seconds
# 2026-02-08 15:53:11,504 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,507 - openai._base_client - INFO - Retrying request to /chat/completions in 0.950183 seconds
# 2026-02-08 15:53:11,508 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,510 - openai._base_client - INFO - Retrying request to /chat/completions in 0.758670 seconds
# 2026-02-08 15:53:11,544 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,545 - openai._base_client - INFO - Retrying request to /chat/completions in 0.762805 seconds
# 2026-02-08 15:53:11,547 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,548 - openai._base_client - INFO - Retrying request to /chat/completions in 0.385614 seconds
# 2026-02-08 15:53:11,644 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,646 - openai._base_client - INFO - Retrying request to /chat/completions in 0.809899 seconds
# 2026-02-08 15:53:11,709 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,711 - openai._base_client - INFO - Retrying request to /chat/completions in 0.456393 seconds
# 2026-02-08 15:53:11,814 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,816 - openai._base_client - INFO - Retrying request to /chat/completions in 0.995664 seconds
# 2026-02-08 15:53:11,847 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,941 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,943 - openai._base_client - INFO - Retrying request to /chat/completions in 0.758017 seconds
# 2026-02-08 15:53:11,973 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:11,975 - openai._base_client - INFO - Retrying request to /chat/completions in 0.962307 seconds
# 2026-02-08 15:53:11,997 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,030 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,146 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,208 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,210 - openai._base_client - INFO - Retrying request to /chat/completions in 0.770067 seconds
# 2026-02-08 15:53:12,211 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,213 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,215 - openai._base_client - INFO - Retrying request to /chat/completions in 0.467812 seconds
# 2026-02-08 15:53:12,245 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,247 - openai._base_client - INFO - Retrying request to /chat/completions in 0.473030 seconds
# 2026-02-08 15:53:12,280 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,346 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,488 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,490 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,547 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,549 - openai._base_client - INFO - Retrying request to /chat/completions in 0.437237 seconds
# 2026-02-08 15:53:12,732 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,735 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:53:12,737 - openai._base_client - INFO - Retrying request to /chat/completions in 0.851106 seconds
# ...
# 2026-02-08 15:58:12,324 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:12,354 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:12,356 - openai._base_client - INFO - Retrying request to /chat/completions in 0.452914 seconds
# 2026-02-08 15:58:12,669 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:12,671 - openai._base_client - INFO - Retrying request to /chat/completions in 0.964527 seconds
# 2026-02-08 15:58:12,774 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:12,839 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:12,841 - openai._base_client - INFO - Retrying request to /chat/completions in 0.967915 seconds
# 2026-02-08 15:58:13,056 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:13,057 - openai._base_client - INFO - Retrying request to /chat/completions in 0.445370 seconds
# 2026-02-08 15:58:13,533 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:13,535 - openai._base_client - INFO - Retrying request to /chat/completions in 0.799465 seconds
# 2026-02-08 15:58:13,667 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:13,849 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:13,909 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:13,911 - openai._base_client - INFO - Retrying request to /chat/completions in 0.493332 seconds
# 2026-02-08 15:58:14,364 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:14,371 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:14,373 - ragas.executor - ERROR - Exception raised in Job[17]: RateLimitError(Error code: 429 - {'error': {'message': "You've reached your API request limit. Please wait and try again later. If your use case requires a higher rate limit, please refer to our Pricing - commitment tier at https://www.upstage.ai/pricing/api#commitment to see how rate limits are determined based on your commitment amount", 'type': 'too_many_requests', 'param': '', 'code': 'too_many_requests'}})
# 2026-02-08 15:58:14,429 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:14,431 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:14,432 - openai._base_client - INFO - Retrying request to /chat/completions in 0.765703 seconds
# 2026-02-08 15:58:14,703 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:14,704 - openai._base_client - INFO - Retrying request to /chat/completions in 0.492350 seconds
# 2026-02-08 15:58:15,273 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:15,281 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:15,282 - openai._base_client - INFO - Retrying request to /chat/completions in 0.771343 seconds
# 2026-02-08 15:58:15,296 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:15,297 - openai._base_client - INFO - Retrying request to /chat/completions in 0.476966 seconds
# 2026-02-08 15:58:16,096 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:16,098 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:16,099 - openai._base_client - INFO - Retrying request to /chat/completions in 0.429316 seconds
# 2026-02-08 15:58:16,561 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:16,562 - openai._base_client - INFO - Retrying request to /chat/completions in 0.817324 seconds
# 2026-02-08 15:58:17,461 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:17,478 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:17,479 - openai._base_client - INFO - Retrying request to /chat/completions in 0.415190 seconds
# 2026-02-08 15:58:17,930 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:17,931 - openai._base_client - INFO - Retrying request to /chat/completions in 0.993518 seconds
# 2026-02-08 15:58:18,414 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:18,416 - openai._base_client - INFO - Retrying request to /chat/completions in 0.484558 seconds
# 2026-02-08 15:58:18,902 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:18,904 - openai._base_client - INFO - Retrying request to /chat/completions in 0.434526 seconds
# 2026-02-08 15:58:18,931 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:18,933 - openai._base_client - INFO - Retrying request to /chat/completions in 0.970163 seconds
# 2026-02-08 15:58:18,962 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:18,965 - ragas.executor - ERROR - Exception raised in Job[22]: RateLimitError(Error code: 429 - {'error': {'message': "You've reached your API request limit. Please wait and try again later. If your use case requires a higher rate limit, please refer to our Pricing - commitment tier at https://www.upstage.ai/pricing/api#commitment to see how rate limits are determined based on your commitment amount", 'type': 'too_many_requests', 'param': '', 'code': 'too_many_requests'}})
# 2026-02-08 15:58:19,382 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:19,383 - openai._base_client - INFO - Retrying request to /chat/completions in 0.848807 seconds
# 2026-02-08 15:58:19,949 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:20,260 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:20,262 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:20,263 - openai._base_client - INFO - Retrying request to /chat/completions in 0.449304 seconds
# 2026-02-08 15:58:23,494 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:24,365 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:26,996 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:28,982 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:29,021 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:29,022 - openai._base_client - INFO - Retrying request to /chat/completions in 0.480901 seconds
# 2026-02-08 15:58:29,537 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:29,538 - openai._base_client - INFO - Retrying request to /chat/completions in 0.766155 seconds
# 2026-02-08 15:58:31,443 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:32,630 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:32,738 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:58:32,740 - ragas.executor - ERROR - Exception raised in Job[27]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:58:34,348 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:37,276 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:37,310 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:37,312 - openai._base_client - INFO - Retrying request to /chat/completions in 0.379707 seconds
# 2026-02-08 15:58:37,734 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:37,736 - openai._base_client - INFO - Retrying request to /chat/completions in 0.919612 seconds
# 2026-02-08 15:58:38,695 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:38,739 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:38,740 - openai._base_client - INFO - Retrying request to /chat/completions in 0.470647 seconds
# 2026-02-08 15:58:39,245 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:39,246 - openai._base_client - INFO - Retrying request to /chat/completions in 0.774608 seconds
# 2026-02-08 15:58:40,061 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:42,337 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:42,367 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:42,368 - openai._base_client - INFO - Retrying request to /chat/completions in 0.466200 seconds
# 2026-02-08 15:58:42,885 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:42,887 - openai._base_client - INFO - Retrying request to /chat/completions in 0.832658 seconds
# 2026-02-08 15:58:43,792 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:43,907 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:43,956 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 400 Bad Request"
# 2026-02-08 15:58:43,957 - ragas.executor - ERROR - Exception raised in Job[39]: BadRequestError(Error code: 400 - {'error': {'message': "'$.input' is invalid. Please check the API reference: https://developers.upstage.ai/docs/apis/embeddings", 'type': 'invalid_request_error', 'param': 'input', 'code': None}})
# 2026-02-08 15:58:44,243 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:45,561 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:45,604 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:45,605 - openai._base_client - INFO - Retrying request to /chat/completions in 0.400521 seconds
# 2026-02-08 15:58:46,039 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:46,040 - openai._base_client - INFO - Retrying request to /chat/completions in 0.919602 seconds
# 2026-02-08 15:58:46,994 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:47,348 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:47,349 - openai._base_client - INFO - Retrying request to /chat/completions in 0.421192 seconds
# 2026-02-08 15:58:47,811 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-02-08 15:58:47,812 - openai._base_client - INFO - Retrying request to /chat/completions in 0.950044 seconds
# 2026-02-08 15:58:50,143 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-08 15:58:51,860 - ragas.executor - ERROR - Exception raised in Job[0]: TimeoutError()0 [02:58<00:08,  4.34s/it]
# 2026-02-08 15:58:58,535 - ragas.executor - ERROR - Exception raised in Job[23]: TimeoutError() [03:00<00:03,  3.58s/it]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 40/40 [03:06<00:00,  4.67s/it]
# ✅ run_dir: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859
# ✅ saved: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\summary.csv C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\detail.csv C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\meta.json
# ✅ delta saved: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\delta_summary.csv C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\delta_detail.csv
# ✅ top changes metric: answer_relevancy_delta
# ✅ top regressions: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\top_regressions.csv
# ✅ top improvements: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\top_improvements.csv
# ✅ extra saved config : C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\config.json
# ✅ extra saved samples: C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\samples_base.jsonl and C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\samples_exp.jsonl
# ✅ extra saved trace  : C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0038_20260208_155859\trace.jsonl
# ✅ trace columns used : ['question', 'answer', 'ground_truth', 'reference', 'contexts', '_trace', 'run_tag']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\darks\Desktop\자료들\AI자료\ai\source\chatbot_app\results\ragas_runs\ragas_compare_0037_20260208_153636\detail.csv")   # 또는 정확한 경로
row = df.iloc[0]

print(type(row["contexts"]))
print(row["contexts"][:200])
# Out:
# <class 'str'>
# ["page_content='이 법에 위반된 약정(約定)으로서 임차인에게 불리한 것은 그 효력이 없다.\n\n[전문개정 2008. 3. 21.]' metadata={'article': '제10조(강행규정)', 'category': ['특약_유효성', '손해배상_책임'], 'chunk_id': '주택임대차보호법(법률)(제21065호)(20260102)_019
